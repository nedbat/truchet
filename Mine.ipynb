# %%
from carlson import show_tiles, carlson, carlson_tiles, carlson_demo, carlson_classic
show_tiles(carlson_demo, per_row=8, with_value=True, with_name=True)

# %%
from carlson import value_chart
value_chart(carlson_demo, inverted=True)

# %%
carlson(width=800, height=600, tilew=100, tiles=carlson_classic, nlayers=4, chance=.5, grid=0, seed=128)

# %%
carlson(
    width=2160, height=3840, tilew=240, tiles=carlson_classic, nlayers=5, chance=.4, bg="#335495", fg="#243b6a", 
    format="png", output="~/wallpaper/tru.png",
)
# Out:
# <b><i>Wrote to /Users/nedbatchelder/wallpaper/tru.png</i></b>

# %%
carlson(width=800, height=100, tilew=20, nlayers=3, chance=.5, format="png")

# %%
carlson(width=800, height=100, tilew=20, nlayers=3, chance=.5, format="svg", output="/tmp/carl.svg")
# Out:
# <b><i>Wrote to /tmp/carl.svg</i></b>
