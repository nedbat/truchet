# %%
from smith import smith
smith(tilew=20, seed=5)

# %%
from carlson import carlson_tiles
from tiler import show_tiles, multiscale_truchet
show_tiles(carlson_tiles, width=600, sort=False, frac=.5)

# %%
multiscale_truchet(tiles=carlson_tiles, width=600, height=100, tilew=20, nlayers=3, seed=10)

# %%
multiscale_truchet(tiles=carlson_tiles, width=600, height=300, tilew=60, nlayers=4, chance=.5, seed=11)

# %%
multiscale_truchet(tiles=carlson_tiles, width=800, height=100, tilew=20, nlayers=3, chance=.5, format="png", seed=12)
