# %%
from smith import smith
smith(tilew=20)

# %%
from carlson import show_tiles, carlson, carlson_tiles
show_tiles(carlson_tiles)

# %%
carlson(width=600, height=100, tilew=20, nlayers=1)

# %%
carlson(width=600, height=300, tilew=60, nlayers=4, chance=.5)
