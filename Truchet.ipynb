# %%
from smith import smith
smith(tilew=20, seed=5)

# %%
from carlson import show_tiles, carlson, carlson_tiles
show_tiles(carlson_tiles)

# %%
carlson(width=600, height=100, tilew=20, nlayers=1, seed=10)

# %%
carlson(width=600, height=300, tilew=60, nlayers=4, chance=.5, seed=11)

# %%
carlson(width=800, height=100, tilew=20, nlayers=3, chance=.5, format="png", seed=12)
