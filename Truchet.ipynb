# %%
from smith import smith
smith(tilew=20)

# %%
from carlson import demo, carlson, carlson_tiles
demo(carlson_tiles[0][0:5])

# %%
demo(carlson_tiles[0][5:10])

# %%
demo(carlson_tiles[0][10:15])

# %%
carlson(width=600, height=100, tilew=20, nlayers=1)

# %%
carlson(width=600, height=200, tilew=60, nlayers=4, chance=.45)
